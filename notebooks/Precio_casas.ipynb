# %%
pip install gdown
# Out:
# ...
#
# ...

# %%
import gdown

file_id = '1WhEWuF7LuHr5piiABizIQEnLFnkogq7o'  # Reemplaza con el ID de tu archivo
url = f'https://drive.google.com/uc?id={file_id}'
gdown.download(url, 'casas.csv', quiet=False)  # Cambia 'nombre_del_archivo.ext' al nombre y tipo de archivo
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1WhEWuF7LuHr5piiABizIQEnLFnkogq7o
# To: C:\Users\luzad\MLOps Machine Learning y APIs\casas.csv
# 100%|██████████| 30.3k/30.3k [00:00<00:00, 3.70MB/s]
# 'casas.csv'

# %%
import pandas as pd

df = pd.read_csv('casas.csv')
df.head()
# Out:
#     area  modelo  estacionamiento  precio
# 0  159.0    2003                2  208500
# 1  117.0    1976                2  181500
# 2  166.0    2001                2  223500
# 3  160.0    1915                3  140000
# 4  204.0    2000                3  250000

# %%
df = df[['area','precio']]
df.head()
# Out:
#     area  precio
# 0  159.0  208500
# 1  117.0  181500
# 2  166.0  223500
# 3  160.0  140000
# 4  204.0  250000

# %%
x=df[['area']]
y=df.precio

# %%
pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y,test_size=0.3,random_state=42)

# %%
x_train.head()
# Out:
#        area
# 135   156.0
# 1452  100.0
# 762   144.0
# 932   177.0
# 435   154.0

# %%
from sklearn.linear_model import LinearRegression

modelo = LinearRegression()
modelo.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
modelo.coef_
# Out:
# array([1084.75077747])

# %%
modelo.intercept_
# Out:
# 27206.968559935136

# %%
modelo.predict([[128]])
# Out:
# C:\Users\luzad\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([166055.06807618])

# %%
df = pd.read_csv('casas.csv')
x=df.drop('precio',axis=1)
y=df.precio
x_train, x_test, y_train, y_test = train_test_split(x, y,test_size=0.3,random_state=42)
modelo = LinearRegression()
modelo.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
modelo.predict([[128,1999,1]])
# Out:
# C:\Users\luzad\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([170785.20179426])

# %%
{
    "area":128,
    "modelo":1999,
    "estacionamiento":1
}
# Out:
# {'area': 128, 'modelo': 1999, 'estacionamiento': 1}

# %%
import pickle

with open('modelo.pkl','wb') as file:
    pickle.dump(modelo,file)
# No necesitas files.download para descargar en un entorno local. 
# Simplemente guarda el archivo y luego lo puedes mover o descargar manualmente.
